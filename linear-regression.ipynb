# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv")

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df.shape
# Out:
# (30, 3)

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# #### Here the Unnamed column is not needed, Hence lets drop that column

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %% [markdown]
# #### Now lets find the corelation between the two variables using a heatmap

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# #### Now lets find the linear relationship between the two using a scatter plot

# %%
plt.scatter(df.YearsExperience,df.Salary,color="g",marker="*")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("")
plt.show()

# %% [markdown]
# #### Now we have split the data into x and y

# %%
x=df.iloc[:,:-1]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
print(x)
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y=df.iloc[:,1]
type(y)
# Out:
# pandas.core.series.Series

# %%
print(y)
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Now lets split the dataset into train and test dataset

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (21, 1)
# (9, 1)
# (21,)
# (9,)

# %% [markdown]
# #### Now lets create and fit the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([ 48429.34060881, 125778.60521772,  82910.33808508, 123914.76751631,
#         55884.69141449,  65203.87992159,  66135.7987723 ,  62408.12336946,
#         65203.87992159])

# %%
x_predict=model.predict(x_train)
x_predict
# Out:
# array([ 77318.82498082,  46565.50290739,  69863.47417514, 104344.4716514 ,
#         73591.14957798, 116459.41671063, 109004.06590495,  94093.36429359,
#         91297.60774146,  64271.96107088,  83842.25693579,  38178.23325101,
#        117391.33556134,  75454.9872794 , 111799.82245708,  54952.77256378,
#        101548.71509927,  57748.52911591,  40042.07095243,  41905.90865385,
#         57748.52911591])

# %% [markdown]
# #### Now lets create a Data Frame for the actual & Predicted

# %%
new_df=pd.DataFrame({"Actual":y_test,"Predict":y_predict})
new_df
# Out:
#       Actual        Predict
# 4    39892.0   48429.340609
# 29  121873.0  125778.605218
# 18   81364.0   82910.338085
# 28  122392.0  123914.767516
# 6    60151.0   55884.691414
# 11   55795.0   65203.879922
# 13   57082.0   66135.798772
# 9    57190.0   62408.123369
# 12   56958.0   65203.879922

# %% [markdown]
# ### Now lets visualize the test and train data

# %%
plt.scatter(x_train,y_train,color="r",marker="*")
#plt.plot(x_train,y_predict,color="b")
plt.title("Visualizing training dataset")
plt.show()

# %%
plt.scatter(x_test,y_test,color="r",marker="*")
#plt.plot(x_train,y_predict,color="b")
plt.title("Visualizing test dataset")
plt.show()

# %% [markdown]
# #### Now lets check the Score

# %%
model.score(x_train,y_train)*100
# Out:
# 95.65009666184199

# %%
model.score(x_test,y_test)*100
# Out:
# 94.77717759345151

# %% [markdown]
# #### Here the score is very good for both train and test data
#
# #### Now lets calculate the accuracy of the model

# %% [markdown]
#  - Mean Square Error

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_predict)
# Out:
# 41863660.98720926

# %%
np.sqrt(mean_squared_error(y_test,y_predict))
# Out:
# 6470.213364890625

# %% [markdown]
#  - Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_predict)
# Out:
# 5745.0046664854935

# %% [markdown]
#  - R2 Score

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)*100
# Out:
# 94.77717759345151
