# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fetching data

# %%
df = pd.read_csv("../input/disease-prediction-using-machine-learning/Training.csv")
df.describe()
# Out:
#            itching    skin_rash  nodal_skin_eruptions  continuous_sneezing  \
# count  4920.000000  4920.000000           4920.000000          4920.000000
# mean      0.137805     0.159756              0.021951             0.045122
# std       0.344730     0.366417              0.146539             0.207593
# min       0.000000     0.000000              0.000000             0.000000
# 25%       0.000000     0.000000              0.000000             0.000000
# 50%       0.000000     0.000000              0.000000             0.000000
# 75%       0.000000     0.000000              0.000000             0.000000
# max       1.000000     1.000000              1.000000             1.000000
#
#          shivering       chills   joint_pain  stomach_pain      acidity  \
# count  4920.000000  4920.000000  4920.000000   4920.000000  4920.000000
# mean      0.021951     0.162195     0.139024      0.045122     0.045122
# std       0.146539     0.368667     0.346007      0.207593     0.207593
# min       0.000000     0.000000     0.000000      0.000000     0.000000
# 25%       0.000000     0.000000     0.000000      0.000000     0.000000
# 50%       0.000000     0.000000     0.000000      0.000000     0.000000
# 75%       0.000000     0.000000     0.000000      0.000000     0.000000
# max       1.000000     1.000000     1.000000      1.000000     1.000000
#
#        ulcers_on_tongue  ...   blackheads     scurring  skin_peeling  \
# count       4920.000000  ...  4920.000000  4920.000000   4920.000000
# mean           0.021951  ...     0.021951     0.021951      0.023171
# std            0.146539  ...     0.146539     0.146539      0.150461
# min            0.000000  ...     0.000000     0.000000      0.000000
# 25%            0.000000  ...     0.000000     0.000000      0.000000
# 50%            0.000000  ...     0.000000     0.000000      0.000000
# 75%            0.000000  ...     0.000000     0.000000      0.000000
# max            1.000000  ...     1.000000     1.000000      1.000000
#
#        silver_like_dusting  small_dents_in_nails  inflammatory_nails  \
# count          4920.000000           4920.000000         4920.000000
# mean              0.023171              0.023171            0.023171
# std               0.150461              0.150461            0.150461
# min               0.000000              0.000000            0.000000
# 25%               0.000000              0.000000            0.000000
# 50%               0.000000              0.000000            0.000000
# 75%               0.000000              0.000000            0.000000
# max               1.000000              1.000000            1.000000
#
#            blister  red_sore_around_nose  yellow_crust_ooze  Unnamed: 133
# count  4920.000000           4920.000000        4920.000000           0.0
# mean      0.023171              0.023171           0.023171           NaN
# std       0.150461              0.150461           0.150461           NaN
# min       0.000000              0.000000           0.000000           NaN
# 25%       0.000000              0.000000           0.000000           NaN
# 50%       0.000000              0.000000           0.000000           NaN
# 75%       0.000000              0.000000           0.000000           NaN
# max       1.000000              1.000000           1.000000           NaN
#
# [8 rows x 133 columns]

# %%
df.shape
# Out:
# (4920, 134)

# %%
df.drop('Unnamed: 133', axis=1, inplace=True)
df.columns
# Out:
# Index(['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing',
#        'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity',
#        'ulcers_on_tongue',
#        ...
#        'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting',
#        'small_dents_in_nails', 'inflammatory_nails', 'blister',
#        'red_sore_around_nose', 'yellow_crust_ooze', 'prognosis'],
#       dtype='object', length=133)

# %%
df['prognosis'].value_counts()
# Out:
# Fungal infection                           120
# Hepatitis C                                120
# Hepatitis E                                120
# Alcoholic hepatitis                        120
# Tuberculosis                               120
# Common Cold                                120
# Pneumonia                                  120
# Dimorphic hemmorhoids(piles)               120
# Heart attack                               120
# Varicose veins                             120
# Hypothyroidism                             120
# Hyperthyroidism                            120
# Hypoglycemia                               120
# Osteoarthristis                            120
# Arthritis                                  120
# (vertigo) Paroymsal  Positional Vertigo    120
# Acne                                       120
# Urinary tract infection                    120
# Psoriasis                                  120
# Hepatitis D                                120
# Hepatitis B                                120
# Allergy                                    120
# hepatitis A                                120
# GERD                                       120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# AIDS                                       120
# Diabetes                                   120
# Gastroenteritis                            120
# Bronchial Asthma                           120
# Hypertension                               120
# Migraine                                   120
# Cervical spondylosis                       120
# Paralysis (brain hemorrhage)               120
# Jaundice                                   120
# Malaria                                    120
# Chicken pox                                120
# Dengue                                     120
# Typhoid                                    120
# Impetigo                                   120
# Name: prognosis, dtype: int64

# %% [markdown]
# ## let's split the data for training

# %%
x = df.drop('prognosis', axis = 1)
y = df['prognosis']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Let's train our model

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = tree.predict(x_test)
acc = tree.score(x_test, y_test)

print("Acurray on test set: {:.2f}%".format(acc*100))
# Out:
# Acurray on test set: 100.00%

# %%
fi = pd.DataFrame(tree.feature_importances_*100, x_test.columns, columns=['Importance'])
fi.sort_values(by='Importance',ascending=False, inplace=True)
fi
# Out:
#                      Importance
# mild_fever             4.827496
# throat_irritation      2.645294
# internal_itching       2.638602
# hip_joint_pain         2.609205
# swollen_extremeties    2.586532
# ...                         ...
# swollen_legs           0.000000
# obesity                0.000000
# skin_rash              0.000000
# cramps                 0.000000
# bruising               0.000000
#
# [132 rows x 1 columns]

# %%
zeros = np.array(fi[fi['Importance'] <= 2.300000].index)
zeros
# Out:
# array(['nausea', 'yellowing_of_eyes', 'shivering', 'spotting_ urination',
#        'patches_in_throat', 'receiving_blood_transfusion',
#        'family_history', 'stomach_bleeding', 'ulcers_on_tongue',
#        'diarrhoea', 'constipation', 'pus_filled_pimples', 'sweating',
#        'joint_pain', 'high_fever', 'breathlessness',
#        'nodal_skin_eruptions', 'watering_from_eyes', 'cough',
#        'blackheads', 'stomach_pain', 'vomiting', 'muscle_wasting',
#        'weakness_of_one_body_side', 'chest_pain', 'fatigue',
#        'loss_of_appetite', 'burning_micturition', 'passage_of_gases',
#        'dehydration', 'blister', 'lethargy', 'mucoid_sputum',
#        'indigestion', 'back_pain', 'painful_walking',
#        'swollen_blood_vessels', 'bladder_discomfort',
#        'toxic_look_(typhos)', 'foul_smell_of urine', 'acidity',
#        'weight_gain', 'irritability', 'red_spots_over_body',
#        'sunken_eyes', 'increased_appetite', 'rusty_sputum',
#        'visual_disturbances', 'receiving_unsterile_injections', 'coma',
#        'distention_of_abdomen', 'history_of_alcohol_consumption',
#        'chills', 'continuous_sneezing', 'scurring', 'skin_peeling',
#        'small_dents_in_nails', 'inflammatory_nails',
#        'red_sore_around_nose', 'loss_of_smell', 'mood_swings', 'anxiety',
#        'loss_of_balance', 'pain_during_bowel_movements',
#        'weakness_in_limbs', 'congestion', 'runny_nose', 'sinus_pressure',
#        'redness_of_eyes', 'irregular_sugar_level', 'phlegm',
#        'blurred_and_distorted_vision', 'malaise', 'swelled_lymph_nodes',
#        'swelling_of_stomach', 'fluid_overload', 'acute_liver_failure',
#        'yellow_urine', 'abdominal_pain', 'dark_urine', 'yellowish_skin',
#        'headache', 'pain_in_anal_region', 'bloody_stool',
#        'irritation_in_anus', 'extra_marital_contacts',
#        'spinning_movements', 'cold_hands_and_feets', 'swelling_joints',
#        'stiff_neck', 'muscle_weakness', 'knee_pain', 'slurred_speech',
#        'drying_and_tingling_lips', 'excessive_hunger', 'dizziness',
#        'restlessness', 'brittle_nails', 'enlarged_thyroid',
#        'puffy_face_and_eyes', 'swollen_legs', 'obesity', 'skin_rash',
#        'cramps', 'bruising'], dtype=object)

# %%
training_new = df.drop(columns=zeros, axis=1)
training_new.shape[1]
training_new.columns
# Out:
# Index(['itching', 'weight_loss', 'pain_behind_the_eyes', 'mild_fever',
#        'throat_irritation', 'fast_heart_rate', 'neck_pain',
#        'swollen_extremeties', 'hip_joint_pain', 'movement_stiffness',
#        'unsteadiness', 'continuous_feel_of_urine', 'internal_itching',
#        'depression', 'muscle_pain', 'altered_sensorium', 'belly_pain',
#        'abnormal_menstruation', 'dischromic _patches', 'polyuria',
#        'lack_of_concentration', 'fluid_overload.1', 'blood_in_sputum',
#        'prominent_veins_on_calf', 'palpitations', 'silver_like_dusting',
#        'yellow_crust_ooze', 'prognosis'],
#       dtype='object')

# %%
def modelling(df1):
    x_new = df1.drop('prognosis', axis = 1)
    y_new = df1.prognosis
    x_train_new, x_test_new, y_train_new, y_test_new = train_test_split(x_new, y_new, test_size=0.3, random_state=42) 
    tree.fit(x_train_new, y_train_new)
    
    pred_new = tree.predict(x_test_new)
    
    acc_new = tree.score(x_test_new, y_test_new)
#     a = mean_absolute_error(y_test_new, pred_new)
    print("Acurray on test set: {:.2f}%".format(acc*100))
#     print("mean_absolute_error of the test set: {:.2f}%".format(a))

# %%
test = pd.read_csv("../input/disease-prediction-using-machine-learning/Testing.csv")
test_new = test.drop(columns=zeros, axis=1)
test_new.shape[1]
# Out:
# 28

# %%
modelling(test_new)
# Out:
# Acurray on test set: 100.00%
